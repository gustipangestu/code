# %%
import numpy as np # linear algebra
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from matplotlib import cm

from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler, ConcatDataset
from torch import nn, optim
import torch 
import copy
from sklearn.model_selection import train_test_split

from torchvision import transforms, datasets
import timm 
import timm.optim
from timm.data.transforms_factory import create_transform
from torch.optim import lr_scheduler
import os


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
timm.list_models('mobilenet*',pretrained=True)
# Out:
# ['mobilenet_edgetpu_v2_m.ra4_e3600_r224_in1k',
#  'mobilenetv1_100.ra4_e3600_r224_in1k',
#  'mobilenetv1_100h.ra4_e3600_r224_in1k',
#  'mobilenetv1_125.ra4_e3600_r224_in1k',
#  'mobilenetv2_050.lamb_in1k',
#  'mobilenetv2_100.ra_in1k',
#  'mobilenetv2_110d.ra_in1k',
#  'mobilenetv2_120d.ra_in1k',
#  'mobilenetv2_140.ra_in1k',
#  'mobilenetv3_large_100.miil_in21k',
#  'mobilenetv3_large_100.miil_in21k_ft_in1k',
#  'mobilenetv3_large_100.ra4_e3600_r224_in1k',
#  'mobilenetv3_large_100.ra_in1k',
#  'mobilenetv3_large_150d.ra4_e3600_r256_in1k',
#  'mobilenetv3_rw.rmsp_in1k',
#  'mobilenetv3_small_050.lamb_in1k',
#  'mobilenetv3_small_075.lamb_in1k',
#  'mobilenetv3_small_100.lamb_in1k',
#  'mobilenetv4_conv_aa_large.e230_r384_in12k',
#  'mobilenetv4_conv_aa_large.e230_r384_in12k_ft_in1k',
#  'mobilenetv4_conv_aa_large.e230_r448_in12k_ft_in1k',
#  'mobilenetv4_conv_aa_large.e600_r384_in1k',
#  'mobilenetv4_conv_blur_medium.e500_r224_in1k',
#  'mobilenetv4_conv_large.e500_r256_in1k',
#  'mobilenetv4_conv_large.e600_r384_in1k',
#  'mobilenetv4_conv_medium.e180_ad_r384_in12k',
#  'mobilenetv4_conv_medium.e180_r384_in12k',
#  'mobilenetv4_conv_medium.e250_r384_in12k',
#  'mobilenetv4_conv_medium.e250_r384_in12k_ft_in1k',
#  'mobilenetv4_conv_medium.e500_r224_in1k',
#  'mobilenetv4_conv_medium.e500_r256_in1k',
#  'mobilenetv4_conv_small.e1200_r224_in1k',
#  'mobilenetv4_conv_small.e2400_r224_in1k',
#  'mobilenetv4_conv_small.e3600_r256_in1k',
#  'mobilenetv4_conv_small_050.e3000_r224_in1k',
#  'mobilenetv4_hybrid_large.e600_r384_in1k',
#  'mobilenetv4_hybrid_large.ix_e600_r384_in1k',
#  'mobilenetv4_hybrid_medium.e200_r256_in12k',
#  'mobilenetv4_hybrid_medium.e200_r256_in12k_ft_in1k',
#  'mobilenetv4_hybrid_medium.e500_r224_in1k',
#  'mobilenetv4_hybrid_medium.ix_e550_r256_in1k',
#  'mobilenetv4_hybrid_medium.ix_e550_r384_in1k']

# %%
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands

def mediapipeimg(image):

  with mp_hands.Hands(
    static_image_mode=True,
    max_num_hands=2,
    min_detection_confidence=0.5) as hands:
    results = hands.process(image)
    # print('Handedness:', results.multi_handedness)



    image_height, image_width, _ = image.shape
    annotated_image = image.copy()

    landmark_tangan=[]
    for hand_landmarks in results.multi_hand_landmarks:
     
      mp_drawing.draw_landmarks(
          annotated_image,
          hand_landmarks,
          mp_hands.HAND_CONNECTIONS,
          mp_drawing_styles.get_default_hand_landmarks_style(),
          mp_drawing_styles.get_default_hand_connections_style())
    
    for hand_world_landmarks in results.multi_hand_world_landmarks:
      fitur = []
      data = []
      for h in range(0,20):
          x = hand_world_landmarks.landmark[h].x
          y = hand_world_landmarks.landmark[h].y
          z = hand_world_landmarks.landmark[h].z
          fitur.append(x)
          fitur.append(y)
          fitur.append(z)
      data.extend(fitur)
      x = 0
      y = 0
      z = 0



    return results, annotated_image, data

# %%
import cv2
import math
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import torchvision.transforms as T


base_options = python.BaseOptions(model_asset_path='gesture_recognizer.task')
options = vision.GestureRecognizerOptions(base_options=base_options)
recognizer = vision.GestureRecognizer.create_from_options(options)



def handGesture(img):
    landmarks = []
    errr = None
    # image = mp.Image.create_from_file(img)
    imgPil = T.ToPILImage()(img)
        
    medPil = mp.Image(
            image_format=mp.ImageFormat.SRGB, data=np.asarray(imgPil))
    recognition_result = recognizer.recognize(medPil)
    hand_landmarks = recognition_result.hand_landmarks
    if(len(hand_landmarks) != 0):
        for a in range(0,len(hand_landmarks[0])):
            x = hand_landmarks[0][a].x
            y = hand_landmarks[0][a].y
            z = hand_landmarks[0][a].z
            landmarks.append(x)
            landmarks.append(y)
            landmarks.append(z)
        errr = None
        return landmarks, errr
    else:
        errr = 1
        return landmarks, errr

# %%
# create dataset
import os
from PIL import Image
from torch.utils.data import Dataset
import torchvision.datasets as datasets


class dawtaset(Dataset):
    def __init__(self, image_path, transform=None, featureExtraction=None):
        super(dawtaset, self).__init__()
        self.image_folder = datasets.ImageFolder(image_path)
        self.transform = transform
        self.featureExtraction = featureExtraction
    def __len__(self):
        return len(self.image_folder)
    
    def __getitem__(self, idx):
        image, label = self.image_folder[idx]
        path = self.image_folder.imgs[idx][0]
        data = self.image_folder
        # Apply transformations (if needed)
        if self.transform:
            image = self.transform(image)
        
        if self.featureExtraction:
            feature, err = self.featureExtraction(image)
            if (err != None):
                return self.__getitem__(idx + 1)
            else:
                custom_features = feature
        
        
        hasil = {
            'image': image,
            'labels': label,
            'id_class': idx,
            'custom_features': custom_features,
            'data': data
        }
        
        return hasil

# %%
from torch.utils.data import DataLoader, TensorDataset

train_transform = transforms.Compose([
     transforms.RandomRotation(degrees=(30, 70)),
    transforms.Resize((100, 100)),
    # transforms.Grayscale(1),
    # transforms.RandomHorizontalFlip(p=0.5),
    # transforms.RandomVerticalFlip(p=0.5),
    # transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
   
    transforms.ToTensor(),
   
])
dataset = dawtaset(image_path="asl_dataset", transform=train_transform, featureExtraction=handGesture)

print(type(dataset))
# Out:
# <class '__main__.dawtaset'>

# %%
#Visualizing some examples in the training dataset X
from random import randrange
fig, ax = plt.subplots(nrows = 2, ncols = 5,  figsize = (15,8))
for i in range(5):
    a = randrange(2000)
    hasil = dataset.__getitem__(a)
    
    ax[0,i].imshow(hasil["image"].T, cmap="magma") # Squeeze removes length (1,28,28) -> (28,28)
    ax[0,i].set_title(int(hasil["labels"]))
    

ax[0,0].set_ylabel('Augmented Images',fontdict= {'fontsize':16})
# Out:
# C:\Users\intel\AppData\Local\Temp\ipykernel_22288\2945756074.py:8: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3687.)
#   ax[0,i].imshow(hasil["image"].T, cmap="magma") # Squeeze removes length (1,28,28) -> (28,28)
# Text(0, 0.5, 'Augmented Images')

# %%
hasil = dataset.__getitem__(1)
idx_to_class = {v: k for k, v in hasil["data"].class_to_idx.items()}

def get_class_distribution(dataset):
    count_dict = {k:0 for k,v in hasil["data"].class_to_idx.items()} # initialise dictionary
    
    for input, label in hasil["data"]:
        label = idx_to_class[label]
        count_dict[label] += 1
            
    return count_dict

print("Distribution of classes: ", get_class_distribution(hasil))

get_class_distribution(hasil)
# Out:
# Distribution of classes:  {'0': 70, '1': 70, '2': 70, '3': 70, '4': 70, '5': 70, '6': 70, '7': 70, '8': 70, '9': 70, 'a': 70, 'b': 70, 'c': 70, 'd': 70, 'e': 70, 'f': 70, 'g': 70, 'h': 70, 'i': 70, 'j': 70, 'k': 70, 'l': 70, 'm': 70, 'n': 70, 'o': 70, 'p': 70, 'q': 70, 'r': 70, 's': 70, 't': 65, 'u': 70, 'v': 70, 'w': 70, 'x': 70, 'y': 70, 'z': 70}
# {'0': 70,
#  '1': 70,
#  '2': 70,
#  '3': 70,
#  '4': 70,
#  '5': 70,
#  '6': 70,
#  '7': 70,
#  '8': 70,
#  '9': 70,
#  'a': 70,
#  'b': 70,
#  'c': 70,
#  'd': 70,
#  'e': 70,
#  'f': 70,
#  'g': 70,
#  'h': 70,
#  'i': 70,
#  'j': 70,
#  'k': 70,
#  'l': 70,
#  'm': 70,
#  'n': 70,
#  'o': 70,
#  'p': 70,
#  'q': 70,
#  'r': 70,
#  's': 70,
#  't': 65,
#  'u': 70,
#  'v': 70,
#  'w': 70,
#  'x': 70,
#  'y': 70,
#  'z': 70}

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(dataset)]).melt(), 
            x = "variable", y="value", hue="variable").set_title('Class Distribution of the ASL static Dataset')
# Out:
# Text(0.5, 1.0, 'Class Distribution of the ASL static Dataset')

# %%
train_dataset, val_dataset, test_dataset = random_split(dataset, [1500, 750, 265])

train_loader = DataLoader(dataset=train_dataset, shuffle=False, batch_size=1, drop_last=True)
val_loader = DataLoader(dataset=val_dataset, shuffle=False, batch_size=1)
test_loader = DataLoader(dataset=test_dataset, shuffle=False, batch_size=1)

print("Length of the train_loader:", len(train_loader))
print("Length of the val_loader:", len(val_loader))
print("Length of the test_loader:", len(test_loader))
# Out:
# Length of the train_loader: 1500
# Length of the val_loader: 750
# Length of the test_loader: 265

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,10))
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(train_loader.dataset)]).melt(),
            x = "variable", y="value", hue="variable",  ax=axes[0]).set_title('Train Set')
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(val_loader.dataset)]).melt(), 
            x = "variable", y="value", hue="variable",  ax=axes[1]).set_title('Val Set')
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(test_loader.dataset)]).melt(),
            x = "variable", y="value", hue="variable",  ax=axes[2]).set_title('Test Set')
# Out:
# Text(0.5, 1.0, 'Test Set')

# %%
cnn = timm.create_model('ghostnet_100', pretrained=True)
cnn.classifier.out_features
# Out:
# 1000

# %%
import torch.nn.functional as F

class MyModelDefault(nn.Module):
    def __init__(self):
        super(MyModelDefault, self).__init__()
        self.cnn = timm.create_model('mobilenetv3_small_100', pretrained=True)
        self.cnn.classifier = nn.Linear(
            self.cnn.classifier.in_features, 300
        )
        self.fc1 = nn.Linear(self.cnn.classifier.out_features + 63, 100)
        self.fc2 = nn.Linear(100, 36)
        self.softmax = torch.nn.Softmax()

    def forward(self, image, data):
        x1 = self.cnn(image)
        x2 = data
        x = torch.cat((x1, x2), dim=1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        # x = self.softmax(x)
        return x

model = MyModelDefault()
model
# Out:
# MyModelDefault(
#   (cnn): MobileNetV3(
#     (conv_stem): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNormAct2d(
#       16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#       (drop): Identity()
#       (act): Hardswish()
#     )
#     (blocks): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (bn1): BatchNormAct2d(
#             16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn2): BatchNormAct2d(
#             16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#       )
#       (1): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#           (conv_dw): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (bn2): BatchNormAct2d(
#             72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#           (aa): Identity()
#           (se): Identity()
#           (conv_pwl): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#           (conv_dw): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#           (bn2): BatchNormAct2d(
#             88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#           (aa): Identity()
#           (se): Identity()
#           (conv_pwl): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#       )
#       (2): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (conv_dw): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (bn2): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pwl): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (conv_dw): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (bn2): BatchNormAct2d(
#             240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pwl): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (conv_dw): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (bn2): BatchNormAct2d(
#             240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pwl): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#       )
#       (3): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (conv_dw): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (bn2): BatchNormAct2d(
#             120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pwl): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (conv_dw): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#           (bn2): BatchNormAct2d(
#             144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(40, 144, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pwl): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#       )
#       (4): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#           (bn2): BatchNormAct2d(
#             288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pwl): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (conv_dw): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (bn2): BatchNormAct2d(
#             576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pwl): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (conv_dw): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (bn2): BatchNormAct2d(
#             576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (act1): ReLU(inplace=True)
#             (conv_expand): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Hardsigmoid()
#           )
#           (conv_pwl): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#           (drop_path): Identity()
#         )
#       )
#       (5): Sequential(
#         (0): ConvBnAct(
#           (conv): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNormAct2d(
#             576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Hardswish()
#           )
#           (aa): Identity()
#           (drop_path): Identity()
#         )
#       )
#     )
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Identity())
#     (conv_head): Conv2d(576, 1024, kernel_size=(1, 1), stride=(1, 1))
#     (norm_head): Identity()
#     (act2): Hardswish()
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (classifier): Linear(in_features=1024, out_features=300, bias=True)
#   )
#   (fc1): Linear(in_features=363, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=36, bias=True)
#   (softmax): Softmax(dim=None)
# )

# %%
from torch import tensor
import torchvision.transforms as T
from PIL import Image as im 
# from torch.utils.tensorboard import SummaryWriter
# writer = SummaryWriter()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

model = model.to(device=device)
trainingEpoch_loss = []
validationEpoch_loss = []
validation_acc = []

for epoch in range(100):
    train_loss = 0.0
    for i, data in enumerate(train_loader.dataset, 0):
        
        
        image = torch.as_tensor(data["image"]).unsqueeze(0).to(device=device)
        custom_features = torch.as_tensor(data["custom_features"]).unsqueeze(0).to(device=device)
        labels = torch.as_tensor(data["labels"]).unsqueeze(0).to(device=device)
        optimizer.zero_grad()
        outputs = model(image, 
                        custom_features)
        loss = criterion(outputs, labels)
        # print(torch.as_tensor(data["image"].unsqueeze(0)))
        # print(torch.as_tensor(data["custom_features"]).unsqueeze(0))
        # print(torch.as_tensor(data["labels"]).unsqueeze(0))
        loss.backward()
        optimizer.step()
                # writer.add_scalar("Loss/train", loss, epoch)
        train_loss += loss.item()
        
    valid_loss = 0.0
    model.eval()     # Optional when not using Model Specific layer
    with torch.no_grad():
        total_correct = 0
        total_samples = 0
        for i, data in enumerate(val_loader.dataset, 0): 
            # Forward Pass
            target = model(image, 
                        custom_features)
            # Find the Loss
            loss = criterion(target,labels)
        
            _, predicted = torch.max(target, 1)
            total_correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)
            # Calculate Loss
            valid_loss += loss.item()
        validation_accuracy = total_correct / total_samples
        # print(f"Epoch [{epoch+1}/{epoch}] Validation Accuracy: {validation_accuracy:.4f}")
 
    print(f'Epoch {epoch+1} \t\t Validation Accuracy: {validation_accuracy:.4f} \t\t Training Loss: {train_loss / len(train_loader)} \t\t Validation Loss: {valid_loss / len(val_loader)}')
    trainingEpoch_loss.append(train_loss)
    validationEpoch_loss.append(valid_loss)
    validation_acc.append(validation_accuracy)
# Out:
# Epoch 1 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5840219473838806 		 Validation Loss: 3.5859053134918213
# Epoch 2 		 Validation Accuracy: 0.0000 		 Training Loss: 3.583527792930603 		 Validation Loss: 3.5835189819335938
# Epoch 3 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5835189819335938 		 Validation Loss: 3.5835189819335938
# Epoch 4 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5836657659212747 		 Validation Loss: 3.5835189819335938
# Epoch 5 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5835189819335938 		 Validation Loss: 3.5835189819335938
# Epoch 6 		 Validation Accuracy: 0.0000 		 Training Loss: 3.583520432472229 		 Validation Loss: 3.5835189819335938
# Epoch 7 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5836235156059266 		 Validation Loss: 3.587880849838257
# Epoch 8 		 Validation Accuracy: 0.0000 		 Training Loss: 3.581325263977051 		 Validation Loss: 3.587938070297241
# Epoch 9 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5766525584856668 		 Validation Loss: 3.5835189819335938
# Epoch 10 		 Validation Accuracy: 0.0000 		 Training Loss: 3.583519919236501 		 Validation Loss: 3.5835189819335938
# Epoch 11 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5835659391085306 		 Validation Loss: 3.5835189819335938
# Epoch 12 		 Validation Accuracy: 0.0000 		 Training Loss: 3.573223406950633 		 Validation Loss: 3.5891683101654053
# Epoch 13 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5596368153889975 		 Validation Loss: 3.599803924560547
# Epoch 14 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5444680529435475 		 Validation Loss: 3.595709800720215
# Epoch 15 		 Validation Accuracy: 0.0000 		 Training Loss: 3.537712706565857 		 Validation Loss: 3.5959560871124268
# Epoch 16 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5161724043687186 		 Validation Loss: 3.622555732727051
# Epoch 17 		 Validation Accuracy: 0.0000 		 Training Loss: 3.5053105278015138 		 Validation Loss: 3.5989372730255127
# Epoch 18 		 Validation Accuracy: 0.0000 		 Training Loss: 3.4948745569785435 		 Validation Loss: 3.638434410095215
# Epoch 19 		 Validation Accuracy: 0.0000 		 Training Loss: 3.4793055369059247 		 Validation Loss: 3.5907344818115234
# Epoch 20 		 Validation Accuracy: 0.0000 		 Training Loss: 3.4600603574117024 		 Validation Loss: 3.5904290676116943
# Epoch 21 		 Validation Accuracy: 0.0000 		 Training Loss: 3.448688583175341 		 Validation Loss: 3.601162910461426
# Epoch 22 		 Validation Accuracy: 0.0000 		 Training Loss: 3.4434463086922964 		 Validation Loss: 3.5835189819335938
# Epoch 23 		 Validation Accuracy: 0.0000 		 Training Loss: 3.4197616728742917 		 Validation Loss: 3.5915048122406006
# Epoch 24 		 Validation Accuracy: 0.0000 		 Training Loss: 3.412686384578546 		 Validation Loss: 3.5882344245910645
# Epoch 25 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3927537034948667 		 Validation Loss: 3.589189291000366
# Epoch 26 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3926398169199627 		 Validation Loss: 3.595059394836426
# Epoch 27 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3793073362708093 		 Validation Loss: 3.595701217651367
# Epoch 28 		 Validation Accuracy: 0.0000 		 Training Loss: 3.373758609543244 		 Validation Loss: 3.5839059352874756
# Epoch 29 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3703159734159707 		 Validation Loss: 3.5870144367218018
# Epoch 30 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3583167172918715 		 Validation Loss: 3.588829517364502
# Epoch 31 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3595708198448024 		 Validation Loss: 3.5920779705047607
# Epoch 32 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3493464037875333 		 Validation Loss: 3.5878658294677734
# Epoch 33 		 Validation Accuracy: 0.0000 		 Training Loss: 3.346036734258135 		 Validation Loss: 3.5875518321990967
# Epoch 34 		 Validation Accuracy: 0.0000 		 Training Loss: 3.343092386983335 		 Validation Loss: 3.5857601165771484
# Epoch 35 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3387743025471766 		 Validation Loss: 3.5835189819335938
# Epoch 36 		 Validation Accuracy: 0.0000 		 Training Loss: 3.334579084587594 		 Validation Loss: 3.5835189819335938
# Epoch 37 		 Validation Accuracy: 0.0000 		 Training Loss: 3.331459430369238 		 Validation Loss: 3.591578722000122
# Epoch 38 		 Validation Accuracy: 0.0000 		 Training Loss: 3.319642882697284 		 Validation Loss: 3.614302635192871
# Epoch 39 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3189794807434083 		 Validation Loss: 3.5835189819335938
# Epoch 40 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3111653558276593 		 Validation Loss: 3.618265151977539
# Epoch 41 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3105756888613103 		 Validation Loss: 3.583702802658081
# Epoch 42 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3081910224296154 		 Validation Loss: 3.5893354415893555
# Epoch 43 		 Validation Accuracy: 0.0000 		 Training Loss: 3.305607893654456 		 Validation Loss: 3.642256259918213
# Epoch 44 		 Validation Accuracy: 0.0000 		 Training Loss: 3.3001433053811393 		 Validation Loss: 3.6246979236602783
# Epoch 45 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2864899473302067 		 Validation Loss: 3.597008466720581
# Epoch 46 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2843468126927813 		 Validation Loss: 3.5951249599456787
# Epoch 47 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2830074553191664 		 Validation Loss: 3.6029210090637207
# Epoch 48 		 Validation Accuracy: 0.0000 		 Training Loss: 3.281768313580503 		 Validation Loss: 3.6023378372192383
# Epoch 49 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2671155076014498 		 Validation Loss: 3.5970304012298584
# Epoch 50 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2651777058641116 		 Validation Loss: 3.598099708557129
# Epoch 51 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2482936126658073 		 Validation Loss: 3.60791015625
# Epoch 52 		 Validation Accuracy: 0.0000 		 Training Loss: 3.256654247170314 		 Validation Loss: 3.6121726036071777
# Epoch 53 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2422834423563134 		 Validation Loss: 3.5928239822387695
# Epoch 54 		 Validation Accuracy: 0.0000 		 Training Loss: 3.241270252660538 		 Validation Loss: 3.5981814861297607
# Epoch 55 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2337006490690015 		 Validation Loss: 3.605416774749756
# Epoch 56 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2223765071264157 		 Validation Loss: 3.6109423637390137
# Epoch 57 		 Validation Accuracy: 0.0000 		 Training Loss: 3.2129768580378344 		 Validation Loss: 3.601698398590088
# Epoch 58 		 Validation Accuracy: 0.0000 		 Training Loss: 3.223772588307659 		 Validation Loss: 3.595003128051758
# Epoch 59 		 Validation Accuracy: 0.0000 		 Training Loss: 3.207903750807668 		 Validation Loss: 3.5907323360443115
# Epoch 60 		 Validation Accuracy: 0.0000 		 Training Loss: 3.209281785822784 		 Validation Loss: 3.5947184562683105
# Epoch 61 		 Validation Accuracy: 0.0000 		 Training Loss: 3.201649241058156 		 Validation Loss: 3.602276086807251
# Epoch 62 		 Validation Accuracy: 0.0000 		 Training Loss: 3.18606436574397 		 Validation Loss: 3.5889503955841064
# Epoch 63 		 Validation Accuracy: 0.0000 		 Training Loss: 3.1803915218052765 		 Validation Loss: 3.6004652976989746
# Epoch 64 		 Validation Accuracy: 0.0000 		 Training Loss: 3.1787902997052297 		 Validation Loss: 3.5907442569732666
# Epoch 65 		 Validation Accuracy: 0.0000 		 Training Loss: 3.178210124635448 		 Validation Loss: 3.5901870727539062
# Epoch 66 		 Validation Accuracy: 0.0000 		 Training Loss: 3.1485713156946002 		 Validation Loss: 3.5965576171875
# Epoch 67 		 Validation Accuracy: 0.0000 		 Training Loss: 3.162280788635214 		 Validation Loss: 3.623520851135254
# Epoch 68 		 Validation Accuracy: 0.0000 		 Training Loss: 3.137234210472554 		 Validation Loss: 3.603699207305908
# Epoch 69 		 Validation Accuracy: 0.0000 		 Training Loss: 3.142950698502051 		 Validation Loss: 3.608058452606201
# Epoch 70 		 Validation Accuracy: 0.0000 		 Training Loss: 3.1281881598833325 		 Validation Loss: 3.608065366744995
# Epoch 71 		 Validation Accuracy: 0.0000 		 Training Loss: 3.1109104613425833 		 Validation Loss: 3.6950535774230957
# Epoch 72 		 Validation Accuracy: 0.0000 		 Training Loss: 3.0967525225669768 		 Validation Loss: 3.6260759830474854
# Epoch 73 		 Validation Accuracy: 0.0000 		 Training Loss: 3.0987223522678637 		 Validation Loss: 3.620598554611206
# Epoch 74 		 Validation Accuracy: 0.0000 		 Training Loss: 3.091533316338745 		 Validation Loss: 3.621314525604248
# Epoch 75 		 Validation Accuracy: 0.0000 		 Training Loss: 3.092447480960749 		 Validation Loss: 3.622002601623535
# Epoch 76 		 Validation Accuracy: 0.0000 		 Training Loss: 3.087533167869784 		 Validation Loss: 3.702399730682373
# Epoch 77 		 Validation Accuracy: 0.0000 		 Training Loss: 3.070543551328592 		 Validation Loss: 3.6353251934051514
# Epoch 78 		 Validation Accuracy: 0.0000 		 Training Loss: 3.064458307029369 		 Validation Loss: 3.6386961936950684
# Epoch 79 		 Validation Accuracy: 0.0000 		 Training Loss: 3.053307189200384 		 Validation Loss: 3.647629976272583
# Epoch 80 		 Validation Accuracy: 0.0000 		 Training Loss: 3.041643357063023 		 Validation Loss: 3.674217939376831
# Epoch 81 		 Validation Accuracy: 0.0000 		 Training Loss: 3.035627452149056 		 Validation Loss: 3.6404006481170654
# Epoch 82 		 Validation Accuracy: 0.0000 		 Training Loss: 3.026638370589974 		 Validation Loss: 3.6313998699188232
# Epoch 83 		 Validation Accuracy: 0.0000 		 Training Loss: 3.01536367126011 		 Validation Loss: 3.617910385131836
# Epoch 84 		 Validation Accuracy: 0.0000 		 Training Loss: 3.0269110166129347 		 Validation Loss: 3.627561092376709
# Epoch 85 		 Validation Accuracy: 0.0000 		 Training Loss: 3.0185251505025663 		 Validation Loss: 3.6148738861083984
# Epoch 86 		 Validation Accuracy: 0.0000 		 Training Loss: 3.0006040931458897 		 Validation Loss: 3.613424777984619
# Epoch 87 		 Validation Accuracy: 0.0000 		 Training Loss: 3.004169534933443 		 Validation Loss: 3.616379737854004
# Epoch 88 		 Validation Accuracy: 0.0000 		 Training Loss: 3.001167555522484 		 Validation Loss: 3.683621883392334
# Epoch 89 		 Validation Accuracy: 0.0000 		 Training Loss: 2.997143222534874 		 Validation Loss: 3.599656820297241
# Epoch 90 		 Validation Accuracy: 0.0000 		 Training Loss: 2.9967841869772722 		 Validation Loss: 3.619281768798828
# Epoch 91 		 Validation Accuracy: 0.0000 		 Training Loss: 2.975038930850414 		 Validation Loss: 3.606102705001831
# Epoch 92 		 Validation Accuracy: 0.0000 		 Training Loss: 2.987377767841642 		 Validation Loss: 3.611806869506836
# Epoch 93 		 Validation Accuracy: 0.0000 		 Training Loss: 2.982190088779821 		 Validation Loss: 3.59049916267395
# Epoch 94 		 Validation Accuracy: 0.0000 		 Training Loss: 2.9720345582088146 		 Validation Loss: 3.606694221496582
# Epoch 95 		 Validation Accuracy: 0.0000 		 Training Loss: 2.9862717921008977 		 Validation Loss: 3.5835189819335938
# Epoch 96 		 Validation Accuracy: 0.0000 		 Training Loss: 2.980019129354662 		 Validation Loss: 3.6265687942504883
# Epoch 97 		 Validation Accuracy: 0.0000 		 Training Loss: 2.9648034224067814 		 Validation Loss: 3.6283514499664307
# Epoch 98 		 Validation Accuracy: 0.0000 		 Training Loss: 2.9801100290948526 		 Validation Loss: 3.5945217609405518
# Epoch 99 		 Validation Accuracy: 0.0000 		 Training Loss: 2.9702235346093464 		 Validation Loss: 3.6139471530914307
# Epoch 100 		 Validation Accuracy: 0.0000 		 Training Loss: 2.960081104135296 		 Validation Loss: 3.59303879737854

# %%
torch.save(model.state_dict(), "model_mobilenet+feature")

# %%
from matplotlib import pyplot as plt
plt.plot(trainingEpoch_loss, label='train_loss')
plt.plot(validationEpoch_loss,label='val_loss')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
