# %%
import numpy as np # linear algebra
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from matplotlib import cm

from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler, ConcatDataset
from torch import nn, optim
import torch 
import copy
from sklearn.model_selection import train_test_split

from torchvision import transforms, datasets
import timm 
import timm.optim
from timm.data.transforms_factory import create_transform
from torch.optim import lr_scheduler
import os


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands

def mediapipeimg(image):

  with mp_hands.Hands(
    static_image_mode=True,
    max_num_hands=2,
    min_detection_confidence=0.5) as hands:
    results = hands.process(image)
    # print('Handedness:', results.multi_handedness)



    image_height, image_width, _ = image.shape
    annotated_image = image.copy()

    landmark_tangan=[]
    for hand_landmarks in results.multi_hand_landmarks:
     
      mp_drawing.draw_landmarks(
          annotated_image,
          hand_landmarks,
          mp_hands.HAND_CONNECTIONS,
          mp_drawing_styles.get_default_hand_landmarks_style(),
          mp_drawing_styles.get_default_hand_connections_style())
    
    for hand_world_landmarks in results.multi_hand_world_landmarks:
      fitur = []
      data = []
      for h in range(0,20):
          x = hand_world_landmarks.landmark[h].x
          y = hand_world_landmarks.landmark[h].y
          z = hand_world_landmarks.landmark[h].z
          fitur.append(x)
          fitur.append(y)
          fitur.append(z)
      data.extend(fitur)
      x = 0
      y = 0
      z = 0



    return results, annotated_image, data

# %%
import cv2
import math
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import torchvision.transforms as T


base_options = python.BaseOptions(model_asset_path='gesture_recognizer.task')
options = vision.GestureRecognizerOptions(base_options=base_options)
recognizer = vision.GestureRecognizer.create_from_options(options)



def handGesture(img):
    landmarks = []
    errr = None
    # image = mp.Image.create_from_file(img)
    imgPil = T.ToPILImage()(img)
        
    medPil = mp.Image(
            image_format=mp.ImageFormat.SRGB, data=np.asarray(imgPil))
    recognition_result = recognizer.recognize(medPil)
    hand_landmarks = recognition_result.hand_landmarks
    if(len(hand_landmarks) != 0):
        for a in range(0,len(hand_landmarks[0])):
            x = hand_landmarks[0][a].x
            y = hand_landmarks[0][a].y
            z = hand_landmarks[0][a].z
            landmarks.append(x)
            landmarks.append(y)
            landmarks.append(z)
        errr = None
        return landmarks, errr
    else:
        errr = 1
        return landmarks, errr

# %%
# create dataset
import os
from PIL import Image
from torch.utils.data import Dataset
import torchvision.datasets as datasets


class dawtaset(Dataset):
    def __init__(self, image_path, transform=None, featureExtraction=None):
        super(dawtaset, self).__init__()
        self.image_folder = datasets.ImageFolder(image_path)
        self.transform = transform
        self.featureExtraction = featureExtraction
    def __len__(self):
        return len(self.image_folder)
    
    def __getitem__(self, idx):
        image, label = self.image_folder[idx]
        path = self.image_folder.imgs[idx][0]
        data = self.image_folder
        # Apply transformations (if needed)
        if self.transform:
            image = self.transform(image)
        
        if self.featureExtraction:
            feature, err = self.featureExtraction(image)
            if (err != None):
                return self.__getitem__(idx + 1)
            else:
                custom_features = feature
        
        
        hasil = {
            'image': image,
            'labels': label,
            'id_class': idx,
            'custom_features': custom_features,
            'data': data
        }
        
        return hasil

# %%
from torch.utils.data import DataLoader, TensorDataset

train_transform = transforms.Compose([
     transforms.RandomRotation(degrees=(30, 70)),
    transforms.Resize((100, 100)),
    # transforms.Grayscale(1),
    # transforms.RandomHorizontalFlip(p=0.5),
    # transforms.RandomVerticalFlip(p=0.5),
    # transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
   
    transforms.ToTensor(),
   
])
dataset = dawtaset(image_path="asl_dataset", transform=train_transform, featureExtraction=handGesture)

print(type(dataset))
# Out:
# <class '__main__.dawtaset'>

# %%
#Visualizing some examples in the training dataset X
from random import randrange
fig, ax = plt.subplots(nrows = 2, ncols = 5,  figsize = (15,8))
for i in range(5):
    a = randrange(2000)
    hasil = dataset.__getitem__(a)
    
    ax[0,i].imshow(hasil["image"].T, cmap="magma") # Squeeze removes length (1,28,28) -> (28,28)
    ax[0,i].set_title(int(hasil["labels"]))
    

ax[0,0].set_ylabel('Augmented Images',fontdict= {'fontsize':16})
# Out:
# C:\Users\intel\AppData\Local\Temp\ipykernel_29892\2945756074.py:8: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3687.)
#   ax[0,i].imshow(hasil["image"].T, cmap="magma") # Squeeze removes length (1,28,28) -> (28,28)
# Text(0, 0.5, 'Augmented Images')

# %%
hasil = dataset.__getitem__(1)
idx_to_class = {v: k for k, v in hasil["data"].class_to_idx.items()}

def get_class_distribution(dataset):
    count_dict = {k:0 for k,v in hasil["data"].class_to_idx.items()} # initialise dictionary
    
    for input, label in hasil["data"]:
        label = idx_to_class[label]
        count_dict[label] += 1
            
    return count_dict

print("Distribution of classes: ", get_class_distribution(hasil))

get_class_distribution(hasil)
# Out:
# Distribution of classes:  {'0': 70, '1': 70, '2': 70, '3': 70, '4': 70, '5': 70, '6': 70, '7': 70, '8': 70, '9': 70, 'a': 70, 'b': 70, 'c': 70, 'd': 70, 'e': 70, 'f': 70, 'g': 70, 'h': 70, 'i': 70, 'j': 70, 'k': 70, 'l': 70, 'm': 70, 'n': 70, 'o': 70, 'p': 70, 'q': 70, 'r': 70, 's': 70, 't': 65, 'u': 70, 'v': 70, 'w': 70, 'x': 70, 'y': 70, 'z': 70}
# {'0': 70,
#  '1': 70,
#  '2': 70,
#  '3': 70,
#  '4': 70,
#  '5': 70,
#  '6': 70,
#  '7': 70,
#  '8': 70,
#  '9': 70,
#  'a': 70,
#  'b': 70,
#  'c': 70,
#  'd': 70,
#  'e': 70,
#  'f': 70,
#  'g': 70,
#  'h': 70,
#  'i': 70,
#  'j': 70,
#  'k': 70,
#  'l': 70,
#  'm': 70,
#  'n': 70,
#  'o': 70,
#  'p': 70,
#  'q': 70,
#  'r': 70,
#  's': 70,
#  't': 65,
#  'u': 70,
#  'v': 70,
#  'w': 70,
#  'x': 70,
#  'y': 70,
#  'z': 70}

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(dataset)]).melt(), 
            x = "variable", y="value", hue="variable").set_title('Class Distribution of the ASL static Dataset')
# Out:
# Text(0.5, 1.0, 'Class Distribution of the ASL static Dataset')

# %%
train_dataset, val_dataset, test_dataset = random_split(dataset, [1500, 750, 265])

train_loader = DataLoader(dataset=train_dataset, shuffle=False, batch_size=1, drop_last=True)
val_loader = DataLoader(dataset=val_dataset, shuffle=False, batch_size=1)
test_loader = DataLoader(dataset=test_dataset, shuffle=False, batch_size=1)

print("Length of the train_loader:", len(train_loader))
print("Length of the val_loader:", len(val_loader))
print("Length of the test_loader:", len(test_loader))
# Out:
# Length of the train_loader: 1500
# Length of the val_loader: 750
# Length of the test_loader: 265

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,10))
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(train_loader.dataset)]).melt(),
            x = "variable", y="value", hue="variable",  ax=axes[0]).set_title('Train Set')
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(val_loader.dataset)]).melt(), 
            x = "variable", y="value", hue="variable",  ax=axes[1]).set_title('Val Set')
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(test_loader.dataset)]).melt(),
            x = "variable", y="value", hue="variable",  ax=axes[2]).set_title('Test Set')
# Out:
# Text(0.5, 1.0, 'Test Set')

# %%
import torch.nn.functional as F

class MyModelDefault(nn.Module):
    def __init__(self):
        super(MyModelDefault, self).__init__()
        self.cnn = timm.create_model('resnet10t.c3_in1k', pretrained=True)
        self.cnn.fc = nn.Linear(
            self.cnn.fc.in_features, self.cnn.fc.out_features
        )
        self.fc1 = nn.Linear(self.cnn.fc.out_features, 100)
        self.fc2 = nn.Linear(100, 36)
    def forward(self, image):
        x1 = self.cnn(image)
        
        # x = torch.cat((x1, x2), dim=1)
        
        x = F.relu(self.fc1(x1))
        x = self.fc2(x)
        return x

model = MyModelDefault()
model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 21>()
#      18         x = self.fc2(x)
#      19         return x
# ---> 21 model = MyModelDefault()
#      22 model
#
# Input In [11], in MyModelDefault.__init__(self)
#       5 super(MyModelDefault, self).__init__()
#       6 self.cnn = timm.create_model('ghostnet_100', pretrained=True)
#       7 self.cnn.fc = nn.Linear(
# ----> 8     self.cnn.fc.in_features, self.cnn.fc.out_features
#       9 )
#      10 self.fc1 = nn.Linear(self.cnn.fc.out_features, 100)
#      11 self.fc2 = nn.Linear(100, 36)
#
# File c:\Users\intel\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'GhostNet' object has no attribute 'fc'

# %%
from torch import tensor
import torchvision.transforms as T
from PIL import Image as im 
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

model = model.to(device=device)
trainingEpoch_loss = []
validationEpoch_loss = []
validation_acc = []

for epoch in range(100):
    train_loss = 0.0
    for i, data in enumerate(train_loader.dataset, 0):
        image = torch.as_tensor(data["image"]).unsqueeze(0).to(device=device)
        labels = torch.as_tensor(data["labels"]).unsqueeze(0).to(device=device)
                      
        optimizer.zero_grad()
        outputs = model(image)
        loss = criterion(outputs, labels)
        # print(torch.as_tensor(data["image"].unsqueeze(0)))
        # print(torch.as_tensor(data["custom_features"]).unsqueeze(0))
        # print(torch.as_tensor(data["labels"]).unsqueeze(0))
        loss.backward()
        optimizer.step()
                # writer.add_scalar("Loss/train", loss, epoch)
        train_loss += loss.item()
        
    valid_loss = 0.0
    model.eval()     # Optional when not using Model Specific layer
    with torch.no_grad():
        total_correct = 0
        total_samples = 0
        for i, data in enumerate(val_loader.dataset, 0): 
            image = torch.as_tensor(data["image"]).unsqueeze(0).to(device=device)
            labels = torch.as_tensor(data["labels"]).unsqueeze(0).to(device=device)
            # Forward Pass
            target = model(image)
            # Find the Loss
            loss = criterion(target, labels)
        
            _, predicted = torch.max(target, 1)
            total_correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)
            # Calculate Loss
            valid_loss += loss.item()
        validation_accuracy = total_correct / total_samples
        # print(f"Epoch [{epoch+1}/{epoch}] Validation Accuracy: {validation_accuracy:.4f}")
 
    print(f'Epoch {epoch+1} \t\t Validation Accuracy: {validation_accuracy:.4f} \t\t Training Loss: {train_loss / len(train_loader)} \t\t Validation Loss: {valid_loss / len(val_loader)}')
    trainingEpoch_loss.append(train_loss)
    validationEpoch_loss.append(valid_loss)
    validation_acc.append(validation_accuracy)
# Out:
# Epoch 1 		 Validation Accuracy: 0.8680 		 Training Loss: 0.5882706933551288 		 Validation Loss: 0.34260934293553874
# Epoch 2 		 Validation Accuracy: 0.9093 		 Training Loss: 0.3186833180748724 		 Validation Loss: 0.27421096050323224
# Epoch 3 		 Validation Accuracy: 0.8307 		 Training Loss: 0.24625743010076181 		 Validation Loss: 0.5864478927171283
# Epoch 4 		 Validation Accuracy: 0.7933 		 Training Loss: 0.25798118410551896 		 Validation Loss: 0.9169538402942803
# Epoch 5 		 Validation Accuracy: 0.9267 		 Training Loss: 0.2345830387821027 		 Validation Loss: 0.19045305978292296
# Epoch 6 		 Validation Accuracy: 0.9333 		 Training Loss: 0.1960144753851148 		 Validation Loss: 0.1680016807935011
# Epoch 7 		 Validation Accuracy: 0.9213 		 Training Loss: 0.1581347655749308 		 Validation Loss: 0.25954132059526747
# Epoch 8 		 Validation Accuracy: 0.8973 		 Training Loss: 0.14196951075238365 		 Validation Loss: 0.30850705927088534
# Epoch 9 		 Validation Accuracy: 0.9400 		 Training Loss: 0.15740988634086395 		 Validation Loss: 0.16671224328601203
# Epoch 10 		 Validation Accuracy: 0.9280 		 Training Loss: 0.13009001218254443 		 Validation Loss: 0.19439793311232526
# Epoch 11 		 Validation Accuracy: 0.9547 		 Training Loss: 0.11367109924627278 		 Validation Loss: 0.1248112697219918
# Epoch 12 		 Validation Accuracy: 0.9587 		 Training Loss: 0.0809428567257589 		 Validation Loss: 0.10233312172290547
# Epoch 13 		 Validation Accuracy: 0.9533 		 Training Loss: 0.12020478158464153 		 Validation Loss: 0.13772056705857835
# Epoch 14 		 Validation Accuracy: 0.9520 		 Training Loss: 0.1121930824691618 		 Validation Loss: 0.13709480667680954
# Epoch 15 		 Validation Accuracy: 0.9613 		 Training Loss: 0.09122848503563315 		 Validation Loss: 0.13713558825220318
# Epoch 16 		 Validation Accuracy: 0.9560 		 Training Loss: 0.11216618654903672 		 Validation Loss: 0.12037644045253637
# Epoch 17 		 Validation Accuracy: 0.9667 		 Training Loss: 0.06485291488385496 		 Validation Loss: 0.09008586755403405
# Epoch 18 		 Validation Accuracy: 0.9120 		 Training Loss: 0.06698410938249064 		 Validation Loss: 0.30195506700926744
# Epoch 19 		 Validation Accuracy: 0.9333 		 Training Loss: 0.10655313418167371 		 Validation Loss: 0.2736318035197482
# Epoch 20 		 Validation Accuracy: 0.9373 		 Training Loss: 0.06028215296548971 		 Validation Loss: 0.23979395037216655
# Epoch 21 		 Validation Accuracy: 0.9680 		 Training Loss: 0.09695691539322952 		 Validation Loss: 0.09475883237627772
# Epoch 22 		 Validation Accuracy: 0.9627 		 Training Loss: 0.09009640137638797 		 Validation Loss: 0.1207054774313405
# Epoch 23 		 Validation Accuracy: 0.9427 		 Training Loss: 0.04687957701948716 		 Validation Loss: 0.23255254478319648
# Epoch 24 		 Validation Accuracy: 0.9720 		 Training Loss: 0.077175310412774 		 Validation Loss: 0.08864969044081993
# Epoch 25 		 Validation Accuracy: 0.9547 		 Training Loss: 0.07433682502395385 		 Validation Loss: 0.16352153533420347
# Epoch 26 		 Validation Accuracy: 0.9720 		 Training Loss: 0.08686050926218127 		 Validation Loss: 0.09242116036691642
# Epoch 27 		 Validation Accuracy: 0.9667 		 Training Loss: 0.05979870991723374 		 Validation Loss: 0.23220119588625696
# Epoch 28 		 Validation Accuracy: 0.9747 		 Training Loss: 0.060804758506899606 		 Validation Loss: 0.10697317151179557
# Epoch 29 		 Validation Accuracy: 0.9667 		 Training Loss: 0.05984171854964192 		 Validation Loss: 0.12475150435198017
# Epoch 30 		 Validation Accuracy: 0.9613 		 Training Loss: 0.07825641689665466 		 Validation Loss: 0.1346259115634518
# Epoch 31 		 Validation Accuracy: 0.9680 		 Training Loss: 0.047707193902471016 		 Validation Loss: 0.10553221702184608
# Epoch 32 		 Validation Accuracy: 0.9693 		 Training Loss: 0.0902241072408388 		 Validation Loss: 0.10451482462436877
# Epoch 33 		 Validation Accuracy: 0.9773 		 Training Loss: 0.027271251539953828 		 Validation Loss: 0.09810110969263228
# Epoch 34 		 Validation Accuracy: 0.9520 		 Training Loss: 0.09964622938154367 		 Validation Loss: 0.15081487654426548
# Epoch 35 		 Validation Accuracy: 0.9707 		 Training Loss: 0.06074446035154601 		 Validation Loss: 0.08756756916375412
# Epoch 36 		 Validation Accuracy: 0.9493 		 Training Loss: 0.05088791444581391 		 Validation Loss: 0.19531521217051137
# Epoch 37 		 Validation Accuracy: 0.9720 		 Training Loss: 0.052271935473395086 		 Validation Loss: 0.12649524425574263
# Epoch 38 		 Validation Accuracy: 0.9667 		 Training Loss: 0.061892417925910784 		 Validation Loss: 0.11391575342030566
# Epoch 39 		 Validation Accuracy: 0.9760 		 Training Loss: 0.04622355135552474 		 Validation Loss: 0.11444478051010094
# Epoch 40 		 Validation Accuracy: 0.8587 		 Training Loss: 0.044454325232428496 		 Validation Loss: 0.562881493305347
# Epoch 41 		 Validation Accuracy: 0.9733 		 Training Loss: 0.06392220526718521 		 Validation Loss: 0.09472936700278489
# Epoch 42 		 Validation Accuracy: 0.9680 		 Training Loss: 0.0401733579605078 		 Validation Loss: 0.15747094703799716
# Epoch 43 		 Validation Accuracy: 0.9813 		 Training Loss: 0.033138640077479624 		 Validation Loss: 0.11838314788033903
# Epoch 44 		 Validation Accuracy: 0.9800 		 Training Loss: 0.04217737090590734 		 Validation Loss: 0.09857252650095572
# Epoch 45 		 Validation Accuracy: 0.9520 		 Training Loss: 0.04565525605900134 		 Validation Loss: 0.20302573181122785
# Epoch 46 		 Validation Accuracy: 0.9800 		 Training Loss: 0.054961671706681176 		 Validation Loss: 0.12347627283775607
# Epoch 47 		 Validation Accuracy: 0.9707 		 Training Loss: 0.07332876139725952 		 Validation Loss: 0.1440208502270988
# Epoch 48 		 Validation Accuracy: 0.9720 		 Training Loss: 0.023192659522942492 		 Validation Loss: 0.132988310142721
# Epoch 49 		 Validation Accuracy: 0.9773 		 Training Loss: 0.04197221873785165 		 Validation Loss: 0.07794016290617856
# Epoch 50 		 Validation Accuracy: 0.9720 		 Training Loss: 0.0486504181558894 		 Validation Loss: 0.13478192699470506
# Epoch 51 		 Validation Accuracy: 0.9493 		 Training Loss: 0.043885041031085106 		 Validation Loss: 0.27585091054240896
# Epoch 52 		 Validation Accuracy: 0.9760 		 Training Loss: 0.05712254705287836 		 Validation Loss: 0.09617574566958319
# Epoch 53 		 Validation Accuracy: 0.9787 		 Training Loss: 0.02041674701879962 		 Validation Loss: 0.1225154522681795
# Epoch 54 		 Validation Accuracy: 0.9840 		 Training Loss: 0.023373420993214565 		 Validation Loss: 0.10185322334197035
# Epoch 55 		 Validation Accuracy: 0.9693 		 Training Loss: 0.03593740186448687 		 Validation Loss: 0.12640824272492304
# Epoch 56 		 Validation Accuracy: 0.9693 		 Training Loss: 0.039357796431857855 		 Validation Loss: 0.17213844820242705
# Epoch 57 		 Validation Accuracy: 0.9760 		 Training Loss: 0.027576581118847435 		 Validation Loss: 0.1377998452635823
# Epoch 58 		 Validation Accuracy: 0.9707 		 Training Loss: 0.04457313157545815 		 Validation Loss: 0.0833492095603889
# Epoch 59 		 Validation Accuracy: 0.9800 		 Training Loss: 0.02385984352204257 		 Validation Loss: 0.1103896567032023
# Epoch 60 		 Validation Accuracy: 0.9827 		 Training Loss: 0.02574429869155949 		 Validation Loss: 0.06722053666484086
# Epoch 61 		 Validation Accuracy: 0.9720 		 Training Loss: 0.038577788549111314 		 Validation Loss: 0.12189868394653039
# Epoch 62 		 Validation Accuracy: 0.9613 		 Training Loss: 0.08171036353791161 		 Validation Loss: 0.14487949689716806
# Epoch 63 		 Validation Accuracy: 0.9600 		 Training Loss: 0.0280934772267522 		 Validation Loss: 0.19764689760306356
# Epoch 64 		 Validation Accuracy: 0.9813 		 Training Loss: 0.01880457289349845 		 Validation Loss: 0.11567760994506485
# Epoch 65 		 Validation Accuracy: 0.9680 		 Training Loss: 0.09226298235229516 		 Validation Loss: 0.09691705538342099
# Epoch 66 		 Validation Accuracy: 0.9827 		 Training Loss: 0.022674998197202933 		 Validation Loss: 0.0976100974073856
# Epoch 67 		 Validation Accuracy: 0.9653 		 Training Loss: 0.046584289076398874 		 Validation Loss: 0.12743443185622827
# Epoch 68 		 Validation Accuracy: 0.9747 		 Training Loss: 0.039618300261128156 		 Validation Loss: 0.0959192522970457
# Epoch 69 		 Validation Accuracy: 0.9840 		 Training Loss: 0.0006696235194712017 		 Validation Loss: 0.10733307314672179
# Epoch 70 		 Validation Accuracy: 0.9707 		 Training Loss: 0.05889638231307511 		 Validation Loss: 0.1120242099304146
# Epoch 71 		 Validation Accuracy: 0.9787 		 Training Loss: 0.029510777757629378 		 Validation Loss: 0.12031423733398477
# Epoch 72 		 Validation Accuracy: 0.9787 		 Training Loss: 0.03292507237504382 		 Validation Loss: 0.117834019250847
# Epoch 73 		 Validation Accuracy: 0.9747 		 Training Loss: 0.011583662263895837 		 Validation Loss: 0.11304393765734513
# Epoch 74 		 Validation Accuracy: 0.9493 		 Training Loss: 0.028441851616050548 		 Validation Loss: 0.20790679427887948
# Epoch 75 		 Validation Accuracy: 0.9747 		 Training Loss: 0.0762437611371994 		 Validation Loss: 0.08910637145326465
# Epoch 76 		 Validation Accuracy: 0.9520 		 Training Loss: 0.008424076304949304 		 Validation Loss: 0.1958903637588565
# Epoch 77 		 Validation Accuracy: 0.9800 		 Training Loss: 0.06577390959715579 		 Validation Loss: 0.07157758246303474
# Epoch 78 		 Validation Accuracy: 0.9840 		 Training Loss: 0.021692842067707035 		 Validation Loss: 0.08794301732134159
# Epoch 79 		 Validation Accuracy: 0.9827 		 Training Loss: 0.04372041270094717 		 Validation Loss: 0.1170715056588712
# Epoch 80 		 Validation Accuracy: 0.9640 		 Training Loss: 0.029401297960108045 		 Validation Loss: 0.20702836545135195
# Epoch 81 		 Validation Accuracy: 0.9653 		 Training Loss: 0.03285361638445159 		 Validation Loss: 0.25180540417452785
# Epoch 82 		 Validation Accuracy: 0.9280 		 Training Loss: 0.04723605010837135 		 Validation Loss: 0.3333884029510801
# Epoch 83 		 Validation Accuracy: 0.9787 		 Training Loss: 0.01803304642758899 		 Validation Loss: 0.10430896884776507
# Epoch 84 		 Validation Accuracy: 0.9587 		 Training Loss: 0.006681100047541832 		 Validation Loss: 0.14359687208662172
# Epoch 85 		 Validation Accuracy: 0.9253 		 Training Loss: 0.05162410367916044 		 Validation Loss: 0.3508491471175102
# Epoch 86 		 Validation Accuracy: 0.9800 		 Training Loss: 0.028064581998222267 		 Validation Loss: 0.10735602100566681
# Epoch 87 		 Validation Accuracy: 0.9787 		 Training Loss: 0.0006238904570840399 		 Validation Loss: 0.143128029899822
# Epoch 88 		 Validation Accuracy: 0.9787 		 Training Loss: 0.06845118902948212 		 Validation Loss: 0.1338514769104366
# Epoch 89 		 Validation Accuracy: 0.9280 		 Training Loss: 0.009498961424478708 		 Validation Loss: 0.7662461541351184
# Epoch 90 		 Validation Accuracy: 0.9680 		 Training Loss: 0.07372520790469476 		 Validation Loss: 0.1326850870827032
# Epoch 91 		 Validation Accuracy: 0.9800 		 Training Loss: 0.02149492208026884 		 Validation Loss: 0.09718454626999157
# Epoch 92 		 Validation Accuracy: 0.9693 		 Training Loss: 0.00799316923668054 		 Validation Loss: 0.16822526689551398
# Epoch 93 		 Validation Accuracy: 0.9667 		 Training Loss: 0.04582129160980384 		 Validation Loss: 0.22093476017656827
# Epoch 94 		 Validation Accuracy: 0.9827 		 Training Loss: 0.015715875461032956 		 Validation Loss: 0.14144178560384346
# Epoch 95 		 Validation Accuracy: 0.9773 		 Training Loss: 0.038487621969855314 		 Validation Loss: 0.17537318735423585
# Epoch 96 		 Validation Accuracy: 0.9800 		 Training Loss: 0.02778160992375213 		 Validation Loss: 0.12299518805865375
# Epoch 97 		 Validation Accuracy: 0.9827 		 Training Loss: 0.0373728864672607 		 Validation Loss: 0.10891031968499275
# Epoch 98 		 Validation Accuracy: 0.9813 		 Training Loss: 0.03007244824647797 		 Validation Loss: 0.06805148678106154
# Epoch 99 		 Validation Accuracy: 0.9733 		 Training Loss: 0.004694742862485152 		 Validation Loss: 0.1309510404773288
# Epoch 100 		 Validation Accuracy: 0.9787 		 Training Loss: 0.060069292409758515 		 Validation Loss: 0.09642568461985536

# %%
torch.save(model.state_dict(), "model_ghostnet")

# %%
from matplotlib import pyplot as plt
plt.plot(trainingEpoch_loss, label='train_loss')
plt.plot(validationEpoch_loss,label='val_loss')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
plt.plot(validation_acc, label='val_acc')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
